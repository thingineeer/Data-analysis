# %%
# 스타벅스 도시코드 + 구 번호 통해 ~~시 ~~구 매장몇개인지 어디에 있는지 알아보는 프로그램
# 하지만 미완성.. 마지막 단계에서 막힌다..

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs

# %%
url = "https://www.starbucks.co.kr/store/getGugunList.do"
response = requests.post(url, data = {'sido_cd' : '01'}) # payload ,, 근데 {rndCod : SUQ06HEGU3} 는 안된다..?
dosi_list = response.json()
response.status_code
# Out:
# 200

# %%
seoul = dosi_list["list"] # 서울시에 있는 스타벅스 
seoul
# Out:
# [{'seq': 0,
#   'sido_cd': None,
#   'sido_nm': None,
#   'gugun_cd': '0101',
#   'gugun_nm': '강남구',
#   'code_order': None,
#   'view_yn': None,
#   'store_num': None,
#   'sido': None,
#   'gugun': None,
#   'address': None,
#   'new_img_nm': None,
#   'p_pro_seq': 0,
#   'p_view_yn': None,
#   'p_sido_cd': '',
#   'p_gugun_cd': '',
#   'p_store_nm': None,
#   'p_theme_cd': None,
#   'p_wireless_yn': None,
#   'p_smoking_yn': None,
#   'p_book_yn': None,
#   'p_music_yn': None,
#   'p_terrace_yn': None,
#   'p_table_yn': None,
#   'p_takeout_yn': None,
#   'p_parking_yn': None,
#   'p_dollar_assent': None,
#   'p_card_recharge': None,
#   'p_subway_yn': None,
#   'stb_store_file_renew': None,
#   'stb_store_theme_renew': None,
#   'stb_store_time_renew': None,
#   'stb_store_lsm': None,
#   's_code': None,
#   's_name': None,
#   'tel': None,
#   'fax': None,
#   'sido_code': None,
#   'sido_name': None,
#   'gugun_code': None,
#   'gugun_name': None,
#   'addr': None,
# ...

# %%
df = pd.DataFrame(seoul) # 구별로 정리
df_seoul = df[['gugun_cd', 'gugun_nm']]
df_seoul
# Out:
#    gugun_cd gugun_nm
# 0      0101      강남구
# 1      0120      강동구
# 2      0102      강북구
# 3      0103      강서구
# 4      0104      관악구
# 5      0105      광진구
# 6      0121      구로구
# 7      0106      금천구
# 8      0107      노원구
# 9      0108      도봉구
# 10     0122     동대문구
# 11     0109      동작구
# 12     0110      마포구
# 13     0111     서대문구
# 14     0112      서초구
# 15     0123      성동구
# 16     0113      성북구
# 17     0114      송파구
# 18     0115      양천구
# 19     0116     영등포구
# 20     0124      용산구
# 21     0117      은평구
# 22     0118      종로구
# 23     0119       중구
# 24     0125      중랑구

# %%
df_seoul.columns = [['번호', '이름']]
df_seoul
# Out:
#       번호    이름
# 0   0101   강남구
# 1   0120   강동구
# 2   0102   강북구
# 3   0103   강서구
# 4   0104   관악구
# 5   0105   광진구
# 6   0121   구로구
# 7   0106   금천구
# 8   0107   노원구
# 9   0108   도봉구
# 10  0122  동대문구
# 11  0109   동작구
# 12  0110   마포구
# 13  0111  서대문구
# 14  0112   서초구
# 15  0123   성동구
# 16  0113   성북구
# 17  0114   송파구
# 18  0115   양천구
# 19  0116  영등포구
# 20  0124   용산구
# 21  0117   은평구
# 22  0118   종로구
# 23  0119    중구
# 24  0125   중랑구

# %%
url2 = "https://www.starbucks.co.kr/store/getSidoList.do"
res = requests.post(url2, data ={ 'rndCod' : 'ETGY44EV2Q'})
res.status_code

dosi_list = res.json()

for dosi in dosi_list['list']:
    print(dosi)
# Out:
# {'seq': 0, 'sido_cd': '01', 'sido_nm': '서울', 'gugun_cd': None, 'gugun_nm': None, 'code_order': None, 'view_yn': None, 'store_num': None, 'sido': None, 'gugun': None, 'address': None, 'new_img_nm': None, 'p_pro_seq': 0, 'p_view_yn': None, 'p_sido_cd': '', 'p_gugun_cd': '', 'p_store_nm': None, 'p_theme_cd': None, 'p_wireless_yn': None, 'p_smoking_yn': None, 'p_book_yn': None, 'p_music_yn': None, 'p_terrace_yn': None, 'p_table_yn': None, 'p_takeout_yn': None, 'p_parking_yn': None, 'p_dollar_assent': None, 'p_card_recharge': None, 'p_subway_yn': None, 'stb_store_file_renew': None, 'stb_store_theme_renew': None, 'stb_store_time_renew': None, 'stb_store_lsm': None, 's_code': None, 's_name': None, 'tel': None, 'fax': None, 'sido_code': None, 'sido_name': None, 'gugun_code': None, 'gugun_name': None, 'addr': None, 'park_info': None, 'new_state': None, 'theme_state': None, 'new_bool': 0, 'search_text': '', 'ins_lat': '', 'ins_lng': '', 'in_distance': 0, 'out_distance': None, 'all_search_cnt':
# ...

# %%
for dosi in dosi_list['list']:
    print('도시이름: %s, 코드: %s'%(dosi['sido_nm'], dosi['sido_cd']))
# Out:
# 도시이름: 서울, 코드: 01
# 도시이름: 경기, 코드: 08
# 도시이름: 광주, 코드: 02
# 도시이름: 대구, 코드: 03
# 도시이름: 대전, 코드: 04
# 도시이름: 부산, 코드: 05
# 도시이름: 울산, 코드: 06
# 도시이름: 인천, 코드: 07
# 도시이름: 강원, 코드: 09
# 도시이름: 경남, 코드: 10
# 도시이름: 경북, 코드: 11
# 도시이름: 전남, 코드: 12
# 도시이름: 전북, 코드: 13
# 도시이름: 충남, 코드: 14
# 도시이름: 충북, 코드: 15
# 도시이름: 제주, 코드: 16
# 도시이름: 세종, 코드: 17

# %%
gang_nam = gu_list
gang_nam
# Out:
# {'list': [{'seq': 0,
#    'sido_cd': None,
#    'sido_nm': None,
#    'gugun_cd': '0101',
#    'gugun_nm': '강남구',
#    'code_order': None,
#    'view_yn': None,
#    'store_num': None,
#    'sido': None,
#    'gugun': None,
#    'address': None,
#    'new_img_nm': None,
#    'p_pro_seq': 0,
#    'p_view_yn': None,
#    'p_sido_cd': '',
#    'p_gugun_cd': '',
#    'p_store_nm': None,
#    'p_theme_cd': None,
#    'p_wireless_yn': None,
#    'p_smoking_yn': None,
#    'p_book_yn': None,
#    'p_music_yn': None,
#    'p_terrace_yn': None,
#    'p_table_yn': None,
#    'p_takeout_yn': None,
#    'p_parking_yn': None,
#    'p_dollar_assent': None,
#    'p_card_recharge': None,
#    'p_subway_yn': None,
#    'stb_store_file_renew': None,
#    'stb_store_theme_renew': None,
#    'stb_store_time_renew': None,
#    'stb_store_lsm': None,
#    's_code': None,
#    's_name': None,
#    'tel': None,
#    'fax': None,
#    'sido_code': None,
#    'sido_name': None,
#    'gugun_code': None,
# ...

# %%
# 구군 고유번호, 이름까지는 구했는데 정확한 주소들은 아무리해도 나오지않아서 구글링 헀음.

dosi_code = '01'
gugun_code = '0101'

url2 = 'https://www.istarbucks.co.kr/store/getStore.do?r=KDKCVPIA13'

response = requests.post(url2, data={
        'ins_lat': '37.56682',
        'ins_lng': '126.97865',
        'p_sido_cd': dosi_code,
        'p_gugun_cd': gugun_code,
        'in_biz_cd': '',
        'set_date': '',
 })
response # 404 때문에 진행이 안된다.
# Out:
# <Response [404]>
