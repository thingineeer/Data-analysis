# %% [markdown]
# ## ETF란?
# * ETF(상장지수펀드)는 기초지수의 성과를 추적하는 것이 목표인 인덱스펀드로, 거래소에 상장되어 있어서 개별주식과 마찬가지로 기존의 주식계좌를 통해 거래를 할 수 있습니다. 그 구성종목과 수량 등 자산구성내역(PDF)이 투명하게 공개되어 있고, 장중에는 실시간으로 순자산가치(NAV)가 제공되어 거래에 참고하실 수 있습니다. ETF는 1좌를 거래할 수 있는 최소한의 금액만으로 분산투자 효과를 누릴 수 있어 효율적인 투자수단이며, 펀드보다 운용보수가 낮고 주식에 적용되는 거래세도 붙지 않습니다.
#     * 출처 : [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)
#
#
# ## 크롬 브라우저의 네트워크 정보를 통한 데이터 수집
# * json 데이터 수집과 파일저장 방법
#
# * [ETF : 네이버 금융](https://finance.naver.com/sise/etf.nhn)

# %%
# 라이브러리를 불러옵니다.
# 데이터 분석을 위한 pandas, 수치계산을 위한 numpy, http 요청을 위한 requests를 받아옵니다.
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup as bs

# %%
# 수집할 url을 가져옵니다.
# https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc
url = 'https://finance.naver.com/api/sise/etfItemList.nhn?etfType=0&targetColumn=market_sum&sortOrder=desc'

# %% [markdown]
# ## Pandas를 통한 요청

# %%
# pd.read_html(url)
html = pd.read_html(url)
html # 이걸로 불러 올 수 없음! 이건 table 태그가 있어야함
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27476/1483406860.py in <module>
#       1 # pd.read_html(url)
# ----> 2 html = pd.read_html(url)
#       3 html # 이걸로 불러 올 수 없음! 이건 table 태그가 있어야함
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     924     else:
#     925         assert retained is not None  # for mypy
# --> 926         raise retained
#     927
#     928     ret = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\html.py in _parse_tables(self, doc, match, attrs)
#     550
#     551         if not tables:
# --> 552             raise ValueError("No tables found")
#     553
#     554         result = []
#
# ValueError: No tables found

# %% [markdown]
# ## JSON
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/JSON_vector_logo.svg/300px-JSON_vector_logo.svg.png" width="100">
#
# JSON(제이슨, JavaScript Object Notation)은 속성-값 쌍( attribute–value pairs and array data types (or any other serializable value)) 또는 "키-값 쌍"으로 이루어진 데이터 오브젝트를 전달하기 위해 인간이 읽을 수 있는 텍스트를 사용하는 개방형 표준 포맷이다. 비동기 브라우저/서버 통신 (AJAX)을 위해, 넓게는 XML(AJAX가 사용)을 대체하는 주요 데이터 포맷이다. 특히, 인터넷에서 자료를 주고 받을 때 그 자료를 표현하는 방법으로 알려져 있다. 자료의 종류에 큰 제한은 없으며, 특히 컴퓨터 프로그램의 변수값을 표현하는 데 적합하다.
# 본래는 자바스크립트 언어로부터 파생되어 자바스크립트의 구문 형식을 따르지만 언어 독립형 데이터 포맷이다. 즉, 프로그래밍 언어나 플랫폼에 독립적이므로, 구문 분석 및 JSON 데이터 생성을 위한 코드는 C, C++, C#, 자바, 자바스크립트, 펄, 파이썬 등 수많은 프로그래밍 언어에서 쉽게 이용할 수 있다.
#
# * 출처 : [JSON - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/JSON)

# %% [markdown]
# ## requests를 통한 HTTP 요청
# * [Requests: HTTP for Humans™ — Requests documentation](https://requests.readthedocs.io/en/master/)

# %%
# requests 라이브러리를 통해 url을 받아옵니다.
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
#response.text

# %% [markdown]
# ### JSON 타입으로 데이터 받기

# %%
# requests 의 응답을 json 타입으로 받습니다.
# etf_json
etf_json = response.json()
etf_json
# Out:
# {'resultCode': 'success',
#  'result': {'etfItemList': [{'itemcode': '069500',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200',
#     'nowVal': 35020,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.1,
#     'nav': 35032.0,
#     'threeMonthEarnRate': -4.7898,
#     'quant': 1850237,
#     'amonut': 64855,
#     'marketSum': 50201},
#    {'itemcode': '371460',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나전기차SOLACTIVE',
#     'nowVal': 13715,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.4,
#     'nav': 13710.0,
#     'threeMonthEarnRate': -10.4973,
#     'quant': 3333957,
#     'amonut': 45914,
#     'marketSum': 34781},
#    {'itemcode': '122630',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 레버리지',
#     'nowVal': 18555,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.16,
#     'nav': 18593.0,
#     'threeMonthEarnRate': -10.7229,
#     'quant': 11902227,
#     'amonut': 221307,
#     'marketSum': 23166},
#    {'itemcode': '133690',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국나스닥100',
#     'nowVal': 68040,
#     'risefall': '5',
#     'changeVal': -165,
#     'changeRate': -0.24,
#     'nav': 67261.0,
#     'threeMonthEarnRate': -10.5943,
#     'quant': 161576,
#     'amonut': 10986,
#     'marketSum': 19473},
#    {'itemcode': '214980',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권PLUS',
#     'nowVal': 103885,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 103883.0,
#     'threeMonthEarnRate': 0.2654,
#     'quant': 59834,
#     'amonut': 6215,
#     'marketSum': 18969},
#    {'itemcode': '252670',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 200선물인버스2X',
#     'nowVal': 2625,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.19,
#     'nav': 2631.0,
#     'threeMonthEarnRate': 8.4536,
#     'quant': 85550665,
#     'amonut': 224500,
#     'marketSum': 18866},
#    {'itemcode': '102110',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200',
#     'nowVal': 35075,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.09,
#     'nav': 35073.0,
#     'threeMonthEarnRate': -4.7768,
#     'quant': 509905,
#     'amonut': 17910,
#     'marketSum': 18221},
#    {'itemcode': '157450',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기통안채',
#     'nowVal': 100875,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100871.0,
#     'threeMonthEarnRate': 0.2484,
#     'quant': 67592,
#     'amonut': 6818,
#     'marketSum': 17921},
#    {'itemcode': '360750',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500',
#     'nowVal': 12560,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.32,
#     'nav': 12447.0,
#     'threeMonthEarnRate': -5.2592,
#     'quant': 788304,
#     'amonut': 9889,
#     'marketSum': 15606},
#    {'itemcode': '153130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기채권',
#     'nowVal': 103430,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 103436.0,
#     'threeMonthEarnRate': 0.1937,
#     'quant': 1962515,
#     'amonut': 202992,
#     'marketSum': 14625},
#    {'itemcode': '102780',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹',
#     'nowVal': 8990,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.17,
#     'nav': 9005.0,
#     'threeMonthEarnRate': -0.0223,
#     'quant': 194591,
#     'amonut': 1752,
#     'marketSum': 14303},
#    {'itemcode': '273130',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 종합채권(AA-이상)액티브',
#     'nowVal': 103295,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.03,
#     'nav': 103344.0,
#     'threeMonthEarnRate': -2.6768,
#     'quant': 1646,
#     'amonut': 170,
#     'marketSum': 14064},
#    {'itemcode': '305540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 2차전지테마',
#     'nowVal': 21220,
#     'risefall': '5',
#     'changeVal': -65,
#     'changeRate': -0.31,
#     'nav': 21267.0,
#     'threeMonthEarnRate': 13.6654,
#     'quant': 1449509,
#     'amonut': 30931,
#     'marketSum': 13740},
#    {'itemcode': '305720',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 2차전지산업',
#     'nowVal': 20365,
#     'risefall': '5',
#     'changeVal': -95,
#     'changeRate': -0.46,
#     'nav': 20390.0,
#     'threeMonthEarnRate': 10.7802,
#     'quant': 1490130,
#     'amonut': 30592,
#     'marketSum': 13685},
#    {'itemcode': '381180',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체나스닥',
#     'nowVal': 9970,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.4,
#     'nav': 9835.0,
#     'threeMonthEarnRate': -10.1679,
#     'quant': 1043009,
#     'amonut': 10394,
#     'marketSum': 13410},
#    {'itemcode': '310970',
#     'etfTabCode': 1,
#     'itemname': 'TIGER MSCI Korea TR',
#     'nowVal': 14290,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.03,
#     'nav': 14315.0,
#     'threeMonthEarnRate': -5.2998,
#     'quant': 2816,
#     'amonut': 40,
#     'marketSum': 13218},
#    {'itemcode': '381170',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국테크TOP10 INDXX',
#     'nowVal': 9890,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.35,
#     'nav': 9757.0,
#     'threeMonthEarnRate': -13.6957,
#     'quant': 707782,
#     'amonut': 6987,
#     'marketSum': 12234},
#    {'itemcode': '278530',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 200TR',
#     'nowVal': 11660,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 11667.0,
#     'threeMonthEarnRate': -4.894,
#     'quant': 8800,
#     'amonut': 102,
#     'marketSum': 12086},
#    {'itemcode': '292150',
#     'etfTabCode': 2,
#     'itemname': 'TIGER TOP10',
#     'nowVal': 11500,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 11500.0,
#     'threeMonthEarnRate': -7.534,
#     'quant': 147163,
#     'amonut': 1694,
#     'marketSum': 11857},
#    {'itemcode': '148020',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 200',
#     'nowVal': 35205,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.07,
#     'nav': 35226.0,
#     'threeMonthEarnRate': -4.9832,
#     'quant': 81184,
#     'amonut': 2861,
#     'marketSum': 9787},
#    {'itemcode': '233740',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150레버리지',
#     'nowVal': 11010,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.78,
#     'nav': 11144.0,
#     'threeMonthEarnRate': 0.9237,
#     'quant': 8234245,
#     'amonut': 90432,
#     'marketSum': 9458},
#    {'itemcode': '139260',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 IT',
#     'nowVal': 31740,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.06,
#     'nav': 31807.0,
#     'threeMonthEarnRate': -7.0422,
#     'quant': 62771,
#     'amonut': 1994,
#     'marketSum': 8290},
#    {'itemcode': '114800',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 인버스',
#     'nowVal': 4450,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 4453.0,
#     'threeMonthEarnRate': 4.46,
#     'quant': 11103709,
#     'amonut': 49364,
#     'marketSum': 7707},
#    {'itemcode': '278540',
#     'etfTabCode': 1,
#     'itemname': 'KODEX MSCI Korea TR',
#     'nowVal': 11365,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.09,
#     'nav': 11395.0,
#     'threeMonthEarnRate': -5.4932,
#     'quant': 103176,
#     'amonut': 1175,
#     'marketSum': 7546},
#    {'itemcode': '091180',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 자동차',
#     'nowVal': 18495,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.03,
#     'nav': 18530.0,
#     'threeMonthEarnRate': -0.3072,
#     'quant': 219304,
#     'amonut': 4056,
#     'marketSum': 7019},
#    {'itemcode': '293180',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200',
#     'nowVal': 35100,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.06,
#     'nav': 35099.0,
#     'threeMonthEarnRate': -4.7542,
#     'quant': 315805,
#     'amonut': 11100,
#     'marketSum': 6950},
#    {'itemcode': '394670',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌리튬&2차전지SOLACTIVE(합성)',
#     'nowVal': 10220,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.49,
#     'nav': 10269.0,
#     'threeMonthEarnRate': 0.1951,
#     'quant': 108182,
#     'amonut': 1111,
#     'marketSum': 6950},
#    {'itemcode': '105190',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200',
#     'nowVal': 35090,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.03,
#     'nav': 35085.0,
#     'threeMonthEarnRate': -4.8369,
#     'quant': 70345,
#     'amonut': 2470,
#     'marketSum': 6913},
#    {'itemcode': '152100',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200',
#     'nowVal': 35565,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.08,
#     'nav': 35549.0,
#     'threeMonthEarnRate': -4.8773,
#     'quant': 136660,
#     'amonut': 4859,
#     'marketSum': 6508},
#    {'itemcode': '229200',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스닥150',
#     'nowVal': 12440,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.36,
#     'nav': 12610.0,
#     'threeMonthEarnRate': 1.432,
#     'quant': 2865453,
#     'amonut': 35588,
#     'marketSum': 6027},
#    {'itemcode': '315930',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Top5PlusTR',
#     'nowVal': 17265,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.14,
#     'nav': 17309.0,
#     'threeMonthEarnRate': -8.0075,
#     'quant': 8216,
#     'amonut': 141,
#     'marketSum': 5611},
#    {'itemcode': '294400',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200TR',
#     'nowVal': 42410,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.08,
#     'nav': 42376.0,
#     'threeMonthEarnRate': -4.8502,
#     'quant': 35187,
#     'amonut': 1496,
#     'marketSum': 5365},
#    {'itemcode': '360200',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국S&P500',
#     'nowVal': 12660,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.52,
#     'nav': 12548.0,
#     'threeMonthEarnRate': -5.4075,
#     'quant': 224157,
#     'amonut': 2838,
#     'marketSum': 5317},
#    {'itemcode': '196230',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기통안채',
#     'nowVal': 105180,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 105179.0,
#     'threeMonthEarnRate': 0.2239,
#     'quant': 150423,
#     'amonut': 15821,
#     'marketSum': 5161},
#    {'itemcode': '364980',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX2차전지K-뉴딜',
#     'nowVal': 14555,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.27,
#     'nav': 14587.0,
#     'threeMonthEarnRate': 0.9405,
#     'quant': 440527,
#     'amonut': 6464,
#     'marketSum': 4585},
#    {'itemcode': '190620',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 단기통안채',
#     'nowVal': 100500,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 100507.0,
#     'threeMonthEarnRate': 0.2693,
#     'quant': 2761111,
#     'amonut': 277505,
#     'marketSum': 4543},
#    {'itemcode': '357870',
#     'etfTabCode': 7,
#     'itemname': 'TIGER CD금리투자KIS(합성)',
#     'nowVal': 50835,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.01,
#     'nav': 50844.0,
#     'threeMonthEarnRate': 0.3949,
#     'quant': 62,
#     'amonut': 3,
#     'marketSum': 4506},
#    {'itemcode': '251350',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 선진국MSCI World',
#     'nowVal': 19445,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.26,
#     'nav': 19310.0,
#     'threeMonthEarnRate': -5.4364,
#     'quant': 180177,
#     'amonut': 3509,
#     'marketSum': 4346},
#    {'itemcode': '069660',
#     'etfTabCode': 1,
#     'itemname': 'KOSEF 200',
#     'nowVal': 34965,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.09,
#     'nav': 34983.0,
#     'threeMonthEarnRate': -4.9569,
#     'quant': 183712,
#     'amonut': 6431,
#     'marketSum': 4301},
#    {'itemcode': '379800',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500TR',
#     'nowVal': 11080,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.54,
#     'nav': 10976.0,
#     'threeMonthEarnRate': -5.2858,
#     'quant': 140227,
#     'amonut': 1551,
#     'marketSum': 4061},
#    {'itemcode': '251340',
#     'etfTabCode': 3,
#     'itemname': 'KODEX 코스닥150선물인버스',
#     'nowVal': 4585,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.43,
#     'nav': 4591.0,
#     'threeMonthEarnRate': -4.4606,
#     'quant': 22241288,
#     'amonut': 102246,
#     'marketSum': 4039},
#    {'itemcode': '423160',
#     'etfTabCode': 7,
#     'itemname': 'KODEX KOFR금리액티브(합성)',
#     'nowVal': 100110,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100109.0,
#     'threeMonthEarnRate': None,
#     'quant': 109,
#     'amonut': 10,
#     'marketSum': 4004},
#    {'itemcode': '385540',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS종합채권(A-이상)액티브',
#     'nowVal': 95435,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 95434.0,
#     'threeMonthEarnRate': -2.4682,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 3842},
#    {'itemcode': '400970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn메타버스',
#     'nowVal': 9310,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.38,
#     'nav': 9325.0,
#     'threeMonthEarnRate': -8.1684,
#     'quant': 600400,
#     'amonut': 5584,
#     'marketSum': 3701},
#    {'itemcode': '314250',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국FANG플러스(H)',
#     'nowVal': 19265,
#     'risefall': '5',
#     'changeVal': -220,
#     'changeRate': -1.13,
#     'nav': 19003.0,
#     'threeMonthEarnRate': -24.8844,
#     'quant': 36124,
#     'amonut': 697,
#     'marketSum': 3695},
#    {'itemcode': '367380',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국나스닥100',
#     'nowVal': 11690,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.13,
#     'nav': 11551.0,
#     'threeMonthEarnRate': -10.8439,
#     'quant': 215492,
#     'amonut': 2515,
#     'marketSum': 3647},
#    {'itemcode': '401470',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-메타버스액티브',
#     'nowVal': 8970,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.39,
#     'nav': 8981.0,
#     'threeMonthEarnRate': -9.8148,
#     'quant': 314269,
#     'amonut': 2813,
#     'marketSum': 3601},
#    {'itemcode': '148070',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 국고채10년',
#     'nowVal': 111385,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 111288.0,
#     'threeMonthEarnRate': -3.4876,
#     'quant': 11833,
#     'amonut': 1318,
#     'marketSum': 3497},
#    {'itemcode': '371160',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나항셍테크',
#     'nowVal': 5820,
#     'risefall': '5',
#     'changeVal': -135,
#     'changeRate': -2.27,
#     'nav': 5806.0,
#     'threeMonthEarnRate': -20.1743,
#     'quant': 773346,
#     'amonut': 4546,
#     'marketSum': 3440},
#    {'itemcode': '329750',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국달러단기채권액티브',
#     'nowVal': 10825,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 10833.0,
#     'threeMonthEarnRate': 5.9226,
#     'quant': 45096,
#     'amonut': 487,
#     'marketSum': 3226},
#    {'itemcode': '379810',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100TR',
#     'nowVal': 10010,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.05,
#     'nav': 9900.0,
#     'threeMonthEarnRate': -10.8686,
#     'quant': 150668,
#     'amonut': 1506,
#     'marketSum': 3193},
#    {'itemcode': '226490',
#     'etfTabCode': 1,
#     'itemname': 'KODEX 코스피',
#     'nowVal': 26675,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.02,
#     'nav': 26709.0,
#     'threeMonthEarnRate': -3.4383,
#     'quant': 32802,
#     'amonut': 876,
#     'marketSum': 3174},
#    {'itemcode': '385550',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS단기종합채권(AA-이상)액티브',
#     'nowVal': 100875,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.02,
#     'nav': 100885.0,
#     'threeMonthEarnRate': 0.363,
#     'quant': 238917,
#     'amonut': 24104,
#     'marketSum': 3145},
#    {'itemcode': '143850',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500선물(H)',
#     'nowVal': 46275,
#     'risefall': '2',
#     'changeVal': 155,
#     'changeRate': 0.34,
#     'nav': 46275.0,
#     'threeMonthEarnRate': -10.6808,
#     'quant': 196160,
#     'amonut': 9067,
#     'marketSum': 3043},
#    {'itemcode': '272580',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 단기채권액티브',
#     'nowVal': 50505,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.02,
#     'nav': 50512.0,
#     'threeMonthEarnRate': 0.3277,
#     'quant': 1777,
#     'amonut': 89,
#     'marketSum': 2991},
#    {'itemcode': '367770',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn수소경제테마',
#     'nowVal': 9910,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.4,
#     'nav': 9932.0,
#     'threeMonthEarnRate': 0.1207,
#     'quant': 42237,
#     'amonut': 418,
#     'marketSum': 2899},
#    {'itemcode': '332940',
#     'etfTabCode': 1,
#     'itemname': 'HANARO MSCI Korea TR',
#     'nowVal': 14290,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.32,
#     'nav': 14291.0,
#     'threeMonthEarnRate': -5.286,
#     'quant': 44,
#     'amonut': 0,
#     'marketSum': 2872},
#    {'itemcode': '290130',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR ESG사회책임투자',
#     'nowVal': 11845,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 11865.0,
#     'threeMonthEarnRate': -5.4044,
#     'quant': 32832,
#     'amonut': 388,
#     'marketSum': 2772},
#    {'itemcode': '329200',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 리츠부동산인프라',
#     'nowVal': 6215,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.24,
#     'nav': 6209.0,
#     'threeMonthEarnRate': 5.9343,
#     'quant': 163344,
#     'amonut': 1014,
#     'marketSum': 2685},
#    {'itemcode': '364960',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜',
#     'nowVal': 8250,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.3,
#     'nav': 8270.0,
#     'threeMonthEarnRate': -10.6464,
#     'quant': 413251,
#     'amonut': 3410,
#     'marketSum': 2582},
#    {'itemcode': '414780',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나과창판STAR50(합성)',
#     'nowVal': 7875,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.25,
#     'nav': 8015.0,
#     'threeMonthEarnRate': -13.2418,
#     'quant': 20647,
#     'amonut': 162,
#     'marketSum': 2575},
#    {'itemcode': '213610',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 삼성그룹밸류',
#     'nowVal': 8840,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8852.0,
#     'threeMonthEarnRate': 1.8433,
#     'quant': 1294,
#     'amonut': 11,
#     'marketSum': 2546},
#    {'itemcode': '091170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 은행',
#     'nowVal': 7455,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.47,
#     'nav': 7468.0,
#     'threeMonthEarnRate': -5.8973,
#     'quant': 623802,
#     'amonut': 4630,
#     'marketSum': 2382},
#    {'itemcode': '091160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 반도체',
#     'nowVal': 35225,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.21,
#     'nav': 35306.0,
#     'threeMonthEarnRate': -0.9485,
#     'quant': 70392,
#     'amonut': 2488,
#     'marketSum': 2378},
#    {'itemcode': '394660',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌자율주행&전기차SOLACTIVE',
#     'nowVal': 9660,
#     'risefall': '5',
#     'changeVal': -100,
#     'changeRate': -1.02,
#     'nav': 9583.0,
#     'threeMonthEarnRate': -11.474,
#     'quant': 27965,
#     'amonut': 270,
#     'marketSum': 2365},
#    {'itemcode': '407310',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200 TOP10',
#     'nowVal': 8280,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.3,
#     'nav': 8292.0,
#     'threeMonthEarnRate': -4.5224,
#     'quant': 34,
#     'amonut': 0,
#     'marketSum': 2186},
#    {'itemcode': '228800',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 여행레저',
#     'nowVal': 4535,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.77,
#     'nav': 4535.0,
#     'threeMonthEarnRate': -9.1452,
#     'quant': 309674,
#     'amonut': 1401,
#     'marketSum': 2113},
#    {'itemcode': '325020',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 배당가치',
#     'nowVal': 12610,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.24,
#     'nav': 12632.0,
#     'threeMonthEarnRate': -2.0307,
#     'quant': 524,
#     'amonut': 6,
#     'marketSum': 2106},
#    {'itemcode': '217770',
#     'etfTabCode': 5,
#     'itemname': 'TIGER 원유선물인버스(H)',
#     'nowVal': 2900,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -1.69,
#     'nav': 2897.0,
#     'threeMonthEarnRate': -30.3424,
#     'quant': 1547206,
#     'amonut': 4492,
#     'marketSum': 2074},
#    {'itemcode': '161510',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 고배당주',
#     'nowVal': 12335,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 12349.0,
#     'threeMonthEarnRate': -0.5082,
#     'quant': 50608,
#     'amonut': 623,
#     'marketSum': 2017},
#    {'itemcode': '368590',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국나스닥100',
#     'nowVal': 11335,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 11206.0,
#     'threeMonthEarnRate': -10.8534,
#     'quant': 46162,
#     'amonut': 522,
#     'marketSum': 1938},
#    {'itemcode': '132030',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물(H)',
#     'nowVal': 12485,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.4,
#     'nav': 12489.0,
#     'threeMonthEarnRate': -2.5471,
#     'quant': 80327,
#     'amonut': 1000,
#     'marketSum': 1885},
#    {'itemcode': '401170',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR iSelect메타버스',
#     'nowVal': 8340,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.6,
#     'nav': 8354.0,
#     'threeMonthEarnRate': -12.5805,
#     'quant': 93224,
#     'amonut': 774,
#     'marketSum': 1883},
#    {'itemcode': '295040',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200TR',
#     'nowVal': 12120,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.16,
#     'nav': 12140.0,
#     'threeMonthEarnRate': -4.859,
#     'quant': 22775,
#     'amonut': 276,
#     'marketSum': 1800},
#    {'itemcode': '182480',
#     'etfTabCode': 7,
#     'itemname': 'TIGER 미국MSCI리츠(합성 H)',
#     'nowVal': 13620,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.26,
#     'nav': 13545.0,
#     'threeMonthEarnRate': -9.0757,
#     'quant': 7334,
#     'amonut': 100,
#     'marketSum': 1791},
#    {'itemcode': '168580',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 중국본토CSI300',
#     'nowVal': 26860,
#     'risefall': '5',
#     'changeVal': -265,
#     'changeRate': -0.98,
#     'nav': 27008.0,
#     'threeMonthEarnRate': -11.7887,
#     'quant': 972,
#     'amonut': 26,
#     'marketSum': 1773},
#    {'itemcode': '271050',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물인버스(H)',
#     'nowVal': 4160,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -1.65,
#     'nav': 4161.0,
#     'threeMonthEarnRate': -29.5,
#     'quant': 2783232,
#     'amonut': 11610,
#     'marketSum': 1761},
#    {'itemcode': '412770',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌메타버스액티브',
#     'nowVal': 6900,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.72,
#     'nav': 6868.0,
#     'threeMonthEarnRate': -19.5602,
#     'quant': 289100,
#     'amonut': 1996,
#     'marketSum': 1743},
#    {'itemcode': '326240',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR IT플러스',
#     'nowVal': 18440,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 18484.0,
#     'threeMonthEarnRate': -5.2318,
#     'quant': 1870,
#     'amonut': 34,
#     'marketSum': 1741},
#    {'itemcode': '192090',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300',
#     'nowVal': 10090,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.88,
#     'nav': 10042.0,
#     'threeMonthEarnRate': -11.014,
#     'quant': 255013,
#     'amonut': 2573,
#     'marketSum': 1741},
#    {'itemcode': '275980',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 글로벌4차산업혁신기술(합성 H)',
#     'nowVal': 14935,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.64,
#     'nav': 14814.0,
#     'threeMonthEarnRate': -13.5199,
#     'quant': 10734,
#     'amonut': 160,
#     'marketSum': 1729},
#    {'itemcode': '245710',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 베트남VN30(합성)',
#     'nowVal': 20295,
#     'risefall': '5',
#     'changeVal': -300,
#     'changeRate': -1.46,
#     'nav': 20241.0,
#     'threeMonthEarnRate': -11.7988,
#     'quant': 20390,
#     'amonut': 418,
#     'marketSum': 1684},
#    {'itemcode': '390950',
#     'etfTabCode': 6,
#     'itemname': 'HANARO 단기채권액티브',
#     'nowVal': 100685,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 100695.0,
#     'threeMonthEarnRate': 0.2339,
#     'quant': 363710,
#     'amonut': 36623,
#     'marketSum': 1675},
#    {'itemcode': '379780',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 미국S&P500',
#     'nowVal': 10955,
#     'risefall': '2',
#     'changeVal': 65,
#     'changeRate': 0.6,
#     'nav': 10851.0,
#     'threeMonthEarnRate': -5.5098,
#     'quant': 664075,
#     'amonut': 7265,
#     'marketSum': 1654},
#    {'itemcode': '302450',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스피',
#     'nowVal': 26905,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.13,
#     'nav': 26919.0,
#     'threeMonthEarnRate': -3.8607,
#     'quant': 30,
#     'amonut': 0,
#     'marketSum': 1601},
#    {'itemcode': '329650',
#     'etfTabCode': 7,
#     'itemname': 'KODEX TRF3070',
#     'nowVal': 10840,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.23,
#     'nav': 10804.0,
#     'threeMonthEarnRate': -3.4806,
#     'quant': 5875,
#     'amonut': 63,
#     'marketSum': 1528},
#    {'itemcode': '130730',
#     'etfTabCode': 6,
#     'itemname': 'KOSEF 단기자금',
#     'nowVal': 101370,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 101367.0,
#     'threeMonthEarnRate': 0.3017,
#     'quant': 969,
#     'amonut': 98,
#     'marketSum': 1521},
#    {'itemcode': '143860',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 헬스케어',
#     'nowVal': 29240,
#     'risefall': '2',
#     'changeVal': 450,
#     'changeRate': 1.56,
#     'nav': 29415.0,
#     'threeMonthEarnRate': -3.5834,
#     'quant': 79370,
#     'amonut': 2321,
#     'marketSum': 1480},
#    {'itemcode': '091230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 반도체',
#     'nowVal': 36085,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -0.33,
#     'nav': 36138.0,
#     'threeMonthEarnRate': -0.8083,
#     'quant': 12392,
#     'amonut': 448,
#     'marketSum': 1436},
#    {'itemcode': '219480',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국S&P500선물(H)',
#     'nowVal': 19040,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.45,
#     'nav': 19029.0,
#     'threeMonthEarnRate': -11.0303,
#     'quant': 33342,
#     'amonut': 634,
#     'marketSum': 1409},
#    {'itemcode': '372330',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나항셍테크',
#     'nowVal': 5840,
#     'risefall': '5',
#     'changeVal': -130,
#     'changeRate': -2.18,
#     'nav': 5818.0,
#     'threeMonthEarnRate': -20.0804,
#     'quant': 155881,
#     'amonut': 920,
#     'marketSum': 1387},
#    {'itemcode': '232080',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스닥150',
#     'nowVal': 12725,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 12914.0,
#     'threeMonthEarnRate': 1.7607,
#     'quant': 591531,
#     'amonut': 7526,
#     'marketSum': 1382},
#    {'itemcode': '409820',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100레버리지(합성 H)',
#     'nowVal': 5085,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.2,
#     'nav': 4964.0,
#     'threeMonthEarnRate': -31.7939,
#     'quant': 1500107,
#     'amonut': 7615,
#     'marketSum': 1375},
#    {'itemcode': '138540',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 현대차그룹+펀더멘털',
#     'nowVal': 22805,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.02,
#     'nav': 22802.0,
#     'threeMonthEarnRate': 1.8721,
#     'quant': 4667,
#     'amonut': 106,
#     'marketSum': 1345},
#    {'itemcode': '228810',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 미디어컨텐츠',
#     'nowVal': 7800,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.7,
#     'nav': 7811.0,
#     'threeMonthEarnRate': -5.9957,
#     'quant': 112193,
#     'amonut': 872,
#     'marketSum': 1331},
#    {'itemcode': '270810',
#     'etfTabCode': 1,
#     'itemname': 'KBSTAR 코스닥150',
#     'nowVal': 12400,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 12582.0,
#     'threeMonthEarnRate': 0.4866,
#     'quant': 51092,
#     'amonut': 632,
#     'marketSum': 1307},
#    {'itemcode': '332930',
#     'etfTabCode': 1,
#     'itemname': 'HANARO 200TR',
#     'nowVal': 42455,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.12,
#     'nav': 42436.0,
#     'threeMonthEarnRate': -4.9003,
#     'quant': 35,
#     'amonut': 1,
#     'marketSum': 1274},
#    {'itemcode': '415340',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나과창판STAR50(합성)',
#     'nowVal': 7915,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.06,
#     'nav': 8145.0,
#     'threeMonthEarnRate': -12.2924,
#     'quant': 8562,
#     'amonut': 67,
#     'marketSum': 1227},
#    {'itemcode': '328370',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스피TR',
#     'nowVal': 13575,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.22,
#     'nav': 13614.0,
#     'threeMonthEarnRate': -3.7155,
#     'quant': 341,
#     'amonut': 4,
#     'marketSum': 1215},
#    {'itemcode': '150460',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 중국소비테마',
#     'nowVal': 7300,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.34,
#     'nav': 7308.0,
#     'threeMonthEarnRate': -5.6421,
#     'quant': 10792,
#     'amonut': 78,
#     'marketSum': 1209},
#    {'itemcode': '278240',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 코스닥150선물레버리지',
#     'nowVal': 11825,
#     'risefall': '2',
#     'changeVal': 90,
#     'changeRate': 0.77,
#     'nav': 11823.0,
#     'threeMonthEarnRate': 2.2657,
#     'quant': 1809,
#     'amonut': 21,
#     'marketSum': 1204},
#    {'itemcode': '114260',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국고채3년',
#     'nowVal': 56450,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 0.12,
#     'nav': 56460.0,
#     'threeMonthEarnRate': -1.2956,
#     'quant': 308,
#     'amonut': 17,
#     'marketSum': 1190},
#    {'itemcode': '363570',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 장기종합채권(AA-이상)액티브KAP',
#     'nowVal': 88185,
#     'risefall': '2',
#     'changeVal': 485,
#     'changeRate': 0.55,
#     'nav': 87894.0,
#     'threeMonthEarnRate': -4.5702,
#     'quant': 53,
#     'amonut': 4,
#     'marketSum': 1166},
#    {'itemcode': '309230',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국WideMoat가치주',
#     'nowVal': 17115,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.23,
#     'nav': 16932.0,
#     'threeMonthEarnRate': -3.6128,
#     'quant': 3403,
#     'amonut': 58,
#     'marketSum': 1164},
#    {'itemcode': '261220',
#     'etfTabCode': 5,
#     'itemname': 'KODEX WTI원유선물(H)',
#     'nowVal': 18570,
#     'risefall': '2',
#     'changeVal': 340,
#     'changeRate': 1.87,
#     'nav': 18575.0,
#     'threeMonthEarnRate': 27.9747,
#     'quant': 198257,
#     'amonut': 3678,
#     'marketSum': 1161},
#    {'itemcode': '273140',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 단기변동금리부채권액티브',
#     'nowVal': 103520,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.01,
#     'nav': 103526.0,
#     'threeMonthEarnRate': 0.344,
#     'quant': 1025,
#     'amonut': 106,
#     'marketSum': 1147},
#    {'itemcode': '411420',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국메타버스나스닥액티브',
#     'nowVal': 6705,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.22,
#     'nav': 6623.0,
#     'threeMonthEarnRate': -19.0362,
#     'quant': 25662,
#     'amonut': 171,
#     'marketSum': 1147},
#    {'itemcode': '385560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR KIS국고채30년Enhanced',
#     'nowVal': 78375,
#     'risefall': '2',
#     'changeVal': 140,
#     'changeRate': 0.18,
#     'nav': 78183.0,
#     'threeMonthEarnRate': -11.8886,
#     'quant': 5257,
#     'amonut': 414,
#     'marketSum': 1121},
#    {'itemcode': '363510',
#     'etfTabCode': 6,
#     'itemname': 'SOL KIS단기통안채',
#     'nowVal': 100945,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.0,
#     'nav': 100938.0,
#     'threeMonthEarnRate': 0.2283,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 1118},
#    {'itemcode': '417630',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KEDI혁신기업ESG30',
#     'nowVal': 9795,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.56,
#     'nav': 9805.0,
#     'threeMonthEarnRate': -2.6,
#     'quant': 118056,
#     'amonut': 1155,
#     'marketSum': 1107},
#    {'itemcode': '252710',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물인버스2X',
#     'nowVal': 2750,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 2749.0,
#     'threeMonthEarnRate': 8.4812,
#     'quant': 7708247,
#     'amonut': 21140,
#     'marketSum': 1086},
#    {'itemcode': '395170',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn Top10동일가중',
#     'nowVal': 7835,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 7848.0,
#     'threeMonthEarnRate': -1.7186,
#     'quant': 8702,
#     'amonut': 68,
#     'marketSum': 1050},
#    {'itemcode': '367760',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn5G테크',
#     'nowVal': 9500,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.16,
#     'nav': 9524.0,
#     'threeMonthEarnRate': -0.5228,
#     'quant': 3076,
#     'amonut': 29,
#     'marketSum': 1045},
#    {'itemcode': '365780',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국고채10년',
#     'nowVal': 88495,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.03,
#     'nav': 88410.0,
#     'threeMonthEarnRate': -3.4203,
#     'quant': 560,
#     'amonut': 49,
#     'marketSum': 1004},
#    {'itemcode': '400570',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 유럽탄소배출권선물ICE(H)',
#     'nowVal': 12780,
#     'risefall': '5',
#     'changeVal': -480,
#     'changeRate': -3.62,
#     'nav': 12762.0,
#     'threeMonthEarnRate': -3.2823,
#     'quant': 166416,
#     'amonut': 2125,
#     'marketSum': 965},
#    {'itemcode': '395750',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG가치주액티브',
#     'nowVal': 8450,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8480.0,
#     'threeMonthEarnRate': -3.5389,
#     'quant': 2305,
#     'amonut': 19,
#     'marketSum': 959},
#    {'itemcode': '245360',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나HSCEI',
#     'nowVal': 9165,
#     'risefall': '5',
#     'changeVal': -125,
#     'changeRate': -1.35,
#     'nav': 9180.0,
#     'threeMonthEarnRate': -14.4961,
#     'quant': 1072,
#     'amonut': 9,
#     'marketSum': 944},
#    {'itemcode': '204480',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나CSI300레버리지(합성)',
#     'nowVal': 22090,
#     'risefall': '5',
#     'changeVal': -455,
#     'changeRate': -2.02,
#     'nav': 22305.0,
#     'threeMonthEarnRate': -24.2694,
#     'quant': 31171,
#     'amonut': 696,
#     'marketSum': 941},
#    {'itemcode': '139220',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 건설',
#     'nowVal': 2780,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -1.24,
#     'nav': 2780.0,
#     'threeMonthEarnRate': 0.3207,
#     'quant': 48716,
#     'amonut': 135,
#     'marketSum': 939},
#    {'itemcode': '267770',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 200선물레버리지',
#     'nowVal': 14040,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.07,
#     'nav': 14046.0,
#     'threeMonthEarnRate': -10.4659,
#     'quant': 183072,
#     'amonut': 2578,
#     'marketSum': 927},
#    {'itemcode': '277630',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 코스피',
#     'nowVal': 27125,
#     'risefall': '2',
#     'changeVal': 60,
#     'changeRate': 0.22,
#     'nav': 27144.0,
#     'threeMonthEarnRate': -3.8237,
#     'quant': 873,
#     'amonut': 23,
#     'marketSum': 922},
#    {'itemcode': '245340',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국다우존스30',
#     'nowVal': 20010,
#     'risefall': '2',
#     'changeVal': 50,
#     'changeRate': 0.25,
#     'nav': 19907.0,
#     'threeMonthEarnRate': -3.2571,
#     'quant': 21208,
#     'amonut': 424,
#     'marketSum': 920},
#    {'itemcode': '283580',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나CSI300',
#     'nowVal': 12250,
#     'risefall': '5',
#     'changeVal': -115,
#     'changeRate': -0.93,
#     'nav': 12304.0,
#     'threeMonthEarnRate': -11.5523,
#     'quant': 28235,
#     'amonut': 347,
#     'marketSum': 907},
#    {'itemcode': '261240',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 미국달러선물',
#     'nowVal': 11225,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.13,
#     'nav': 11223.0,
#     'threeMonthEarnRate': 6.105,
#     'quant': 61048,
#     'amonut': 684,
#     'marketSum': 900},
#    {'itemcode': '305080',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 미국채10년선물',
#     'nowVal': 11820,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.3,
#     'nav': 11824.0,
#     'threeMonthEarnRate': 0.2552,
#     'quant': 74763,
#     'amonut': 883,
#     'marketSum': 875},
#    {'itemcode': '423920',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국필라델피아반도체레버리지(합성)',
#     'nowVal': 9595,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.31,
#     'nav': 9355.0,
#     'threeMonthEarnRate': None,
#     'quant': 124768,
#     'amonut': 1195,
#     'marketSum': 858},
#    {'itemcode': '337160',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200ESG',
#     'nowVal': 12930,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 12930.0,
#     'threeMonthEarnRate': -4.4096,
#     'quant': 112,
#     'amonut': 1,
#     'marketSum': 853},
#    {'itemcode': '304940',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국나스닥100선물(H)',
#     'nowVal': 15190,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.07,
#     'nav': 15008.0,
#     'threeMonthEarnRate': -16.0453,
#     'quant': 105327,
#     'amonut': 1598,
#     'marketSum': 851},
#    {'itemcode': '144600',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 은선물(H)',
#     'nowVal': 4440,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.78,
#     'nav': 4446.0,
#     'threeMonthEarnRate': -8.4868,
#     'quant': 183171,
#     'amonut': 813,
#     'marketSum': 848},
#    {'itemcode': '322400',
#     'etfTabCode': 2,
#     'itemname': 'HANARO e커머스',
#     'nowVal': 14800,
#     'risefall': '5',
#     'changeVal': -35,
#     'changeRate': -0.24,
#     'nav': 14822.0,
#     'threeMonthEarnRate': -5.3589,
#     'quant': 243,
#     'amonut': 3,
#     'marketSum': 844},
#    {'itemcode': '325010',
#     'etfTabCode': 2,
#     'itemname': 'KODEX Fn성장',
#     'nowVal': 14650,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.17,
#     'nav': 14691.0,
#     'threeMonthEarnRate': -5.3776,
#     'quant': 205,
#     'amonut': 3,
#     'marketSum': 835},
#    {'itemcode': '364970',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX바이오K-뉴딜',
#     'nowVal': 6590,
#     'risefall': '2',
#     'changeVal': 120,
#     'changeRate': 1.85,
#     'nav': 6605.0,
#     'threeMonthEarnRate': -4.5019,
#     'quant': 633088,
#     'amonut': 4180,
#     'marketSum': 830},
#    {'itemcode': '272560',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 단기국공채액티브',
#     'nowVal': 102540,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': 0.0,
#     'nav': 102543.0,
#     'threeMonthEarnRate': 0.0878,
#     'quant': 248,
#     'amonut': 25,
#     'marketSum': 806},
#    {'itemcode': '363580',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 200IT TR',
#     'nowVal': 12010,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.08,
#     'nav': 12069.0,
#     'threeMonthEarnRate': -7.4075,
#     'quant': 373,
#     'amonut': 4,
#     'marketSum': 805},
#    {'itemcode': '414270',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX G2전기차&자율주행액티브',
#     'nowVal': 8665,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -1.2,
#     'nav': 8691.0,
#     'threeMonthEarnRate': -14.6057,
#     'quant': 215132,
#     'amonut': 1881,
#     'marketSum': 780},
#    {'itemcode': '139280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 경기방어',
#     'nowVal': 9575,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.58,
#     'nav': 9598.0,
#     'threeMonthEarnRate': -2.976,
#     'quant': 1909,
#     'amonut': 18,
#     'marketSum': 776},
#    {'itemcode': '298340',
#     'etfTabCode': 6,
#     'itemname': 'ARIRANG 국채선물3년',
#     'nowVal': 52115,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.05,
#     'nav': 52137.0,
#     'threeMonthEarnRate': -1.2606,
#     'quant': 66,
#     'amonut': 3,
#     'marketSum': 763},
#    {'itemcode': '139230',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 중공업',
#     'nowVal': 3010,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.33,
#     'nav': 3011.0,
#     'threeMonthEarnRate': 4.426,
#     'quant': 176195,
#     'amonut': 531,
#     'marketSum': 742},
#    {'itemcode': '419430',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나2차전지MSCI(합성)',
#     'nowVal': 9470,
#     'risefall': '5',
#     'changeVal': -105,
#     'changeRate': -1.1,
#     'nav': 9535.0,
#     'threeMonthEarnRate': None,
#     'quant': 65268,
#     'amonut': 625,
#     'marketSum': 739},
#    {'itemcode': '117700',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 건설',
#     'nowVal': 3095,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -1.28,
#     'nav': 3092.0,
#     'threeMonthEarnRate': -0.6654,
#     'quant': 113986,
#     'amonut': 352,
#     'marketSum': 737},
#    {'itemcode': '411540',
#     'etfTabCode': 1,
#     'itemname': 'SOL 200 Top10',
#     'nowVal': 8470,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.06,
#     'nav': 8481.0,
#     'threeMonthEarnRate': -4.025,
#     'quant': 168,
#     'amonut': 1,
#     'marketSum': 728},
#    {'itemcode': '157490',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 소프트웨어',
#     'nowVal': 11795,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.3,
#     'nav': 11800.0,
#     'threeMonthEarnRate': -12.5196,
#     'quant': 14996,
#     'amonut': 176,
#     'marketSum': 724},
#    {'itemcode': '298770',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 한국대만IT프리미어',
#     'nowVal': 18220,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.03,
#     'nav': 18112.0,
#     'threeMonthEarnRate': -10.271,
#     'quant': 961,
#     'amonut': 17,
#     'marketSum': 711},
#    {'itemcode': '195980',
#     'etfTabCode': 4,
#     'itemname': 'ARIRANG 신흥국MSCI(합성 H)',
#     'nowVal': 9680,
#     'risefall': '5',
#     'changeVal': -70,
#     'changeRate': -0.72,
#     'nav': 9730.0,
#     'threeMonthEarnRate': -17.7563,
#     'quant': 10705,
#     'amonut': 104,
#     'marketSum': 709},
#    {'itemcode': '228790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 화장품',
#     'nowVal': 2565,
#     'risefall': '2',
#     'changeVal': 25,
#     'changeRate': 0.98,
#     'nav': 2567.0,
#     'threeMonthEarnRate': -14.4782,
#     'quant': 775374,
#     'amonut': 1989,
#     'marketSum': 707},
#    {'itemcode': '385520',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-미래차액티브',
#     'nowVal': 10495,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.1,
#     'nav': 10513.0,
#     'threeMonthEarnRate': 4.4753,
#     'quant': 4484,
#     'amonut': 47,
#     'marketSum': 698},
#    {'itemcode': '385510',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-신재생에너지액티브',
#     'nowVal': 10700,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.7,
#     'nav': 10711.0,
#     'threeMonthEarnRate': 10.8767,
#     'quant': 12784,
#     'amonut': 136,
#     'marketSum': 696},
#    {'itemcode': '266160',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 고배당',
#     'nowVal': 12195,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.04,
#     'nav': 12208.0,
#     'threeMonthEarnRate': -2.5793,
#     'quant': 5051,
#     'amonut': 61,
#     'marketSum': 689},
#    {'itemcode': '123310',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 인버스',
#     'nowVal': 4955,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 4955.0,
#     'threeMonthEarnRate': 4.7568,
#     'quant': 536234,
#     'amonut': 2652,
#     'marketSum': 679},
#    {'itemcode': '390390',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 미국반도체MV',
#     'nowVal': 9965,
#     'risefall': '5',
#     'changeVal': -10,
#     'changeRate': -0.1,
#     'nav': 9870.0,
#     'threeMonthEarnRate': -9.8102,
#     'quant': 14713,
#     'amonut': 146,
#     'marketSum': 668},
#    {'itemcode': '195930',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 유로스탁스50(합성 H)',
#     'nowVal': 12730,
#     'risefall': '2',
#     'changeVal': 95,
#     'changeRate': 0.75,
#     'nav': 12663.0,
#     'threeMonthEarnRate': -10.3265,
#     'quant': 5107,
#     'amonut': 64,
#     'marketSum': 662},
#    {'itemcode': '225040',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 미국S&P500레버리지(합성 H)',
#     'nowVal': 25050,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 0.64,
#     'nav': 24644.0,
#     'threeMonthEarnRate': -22.5094,
#     'quant': 17622,
#     'amonut': 441,
#     'marketSum': 661},
#    {'itemcode': '388280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR Fn컨택트대표',
#     'nowVal': 8655,
#     'risefall': '5',
#     'changeVal': -75,
#     'changeRate': -0.86,
#     'nav': 8680.0,
#     'threeMonthEarnRate': -3.4399,
#     'quant': 5607,
#     'amonut': 48,
#     'marketSum': 653},
#    {'itemcode': '174360',
#     'etfTabCode': 4,
#     'itemname': 'KBSTAR 중국본토대형주CSI100',
#     'nowVal': 18330,
#     'risefall': '5',
#     'changeVal': -275,
#     'changeRate': -1.48,
#     'nav': 18400.0,
#     'threeMonthEarnRate': -11.762,
#     'quant': 1198,
#     'amonut': 22,
#     'marketSum': 642},
#    {'itemcode': '114820',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 국채3년',
#     'nowVal': 106810,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.03,
#     'nav': 106822.0,
#     'threeMonthEarnRate': -1.2677,
#     'quant': 496,
#     'amonut': 52,
#     'marketSum': 641},
#    {'itemcode': '176950',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물10년인버스',
#     'nowVal': 51395,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.1,
#     'nav': 51459.0,
#     'threeMonthEarnRate': 3.8768,
#     'quant': 146,
#     'amonut': 7,
#     'marketSum': 632},
#    {'itemcode': '282000',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 국고채3년선물인버스',
#     'nowVal': 103345,
#     'risefall': '5',
#     'changeVal': -145,
#     'changeRate': -0.14,
#     'nav': 103388.0,
#     'threeMonthEarnRate': 1.6102,
#     'quant': 14,
#     'amonut': 1,
#     'marketSum': 617},
#    {'itemcode': '387280',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 퓨처모빌리티액티브',
#     'nowVal': 10510,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.28,
#     'nav': 10527.0,
#     'threeMonthEarnRate': 3.9447,
#     'quant': 8680,
#     'amonut': 91,
#     'marketSum': 616},
#    {'itemcode': '391600',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 미국친환경그린테마INDXX',
#     'nowVal': 9620,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.41,
#     'nav': 9511.0,
#     'threeMonthEarnRate': 8.9064,
#     'quant': 7703,
#     'amonut': 73,
#     'marketSum': 616},
#    {'itemcode': '200250',
#     'etfTabCode': 4,
#     'itemname': 'KOSEF 인도Nifty50(합성)',
#     'nowVal': 17725,
#     'risefall': '2',
#     'changeVal': 170,
#     'changeRate': 0.97,
#     'nav': 17638.0,
#     'threeMonthEarnRate': -5.8714,
#     'quant': 7292,
#     'amonut': 130,
#     'marketSum': 612},
#    {'itemcode': '396510',
#     'etfTabCode': 4,
#     'itemname': 'TIGER 차이나클린에너지SOLACTIVE',
#     'nowVal': 9360,
#     'risefall': '5',
#     'changeVal': -110,
#     'changeRate': -1.16,
#     'nav': 9356.0,
#     'threeMonthEarnRate': -0.7338,
#     'quant': 23805,
#     'amonut': 224,
#     'marketSum': 599},
#    {'itemcode': '302190',
#     'etfTabCode': 6,
#     'itemname': 'TIGER 중장기국채',
#     'nowVal': 48910,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.01,
#     'nav': 48911.0,
#     'threeMonthEarnRate': -2.4237,
#     'quant': 405,
#     'amonut': 19,
#     'marketSum': 597},
#    {'itemcode': '233160',
#     'etfTabCode': 3,
#     'itemname': 'TIGER 코스닥150 레버리지',
#     'nowVal': 12010,
#     'risefall': '2',
#     'changeVal': 80,
#     'changeRate': 0.67,
#     'nav': 12027.0,
#     'threeMonthEarnRate': 2.7562,
#     'quant': 69507,
#     'amonut': 831,
#     'marketSum': 594},
#    {'itemcode': '310960',
#     'etfTabCode': 1,
#     'itemname': 'TIGER 200TR',
#     'nowVal': 18990,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 18995.0,
#     'threeMonthEarnRate': -4.9074,
#     'quant': 449,
#     'amonut': 8,
#     'marketSum': 589},
#    {'itemcode': '332500',
#     'etfTabCode': 1,
#     'itemname': 'KINDEX 200TR',
#     'nowVal': 21780,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 21779.0,
#     'threeMonthEarnRate': -4.8493,
#     'quant': 354,
#     'amonut': 7,
#     'marketSum': 588},
#    {'itemcode': '396500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER Fn반도체TOP10',
#     'nowVal': 8820,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.06,
#     'nav': 8832.0,
#     'threeMonthEarnRate': -7.0736,
#     'quant': 105227,
#     'amonut': 931,
#     'marketSum': 587},
#    {'itemcode': '099140',
#     'etfTabCode': 4,
#     'itemname': 'KODEX 차이나H',
#     'nowVal': 15960,
#     'risefall': '5',
#     'changeVal': -150,
#     'changeRate': -0.93,
#     'nav': 15804.0,
#     'threeMonthEarnRate': -13.8273,
#     'quant': 2078,
#     'amonut': 33,
#     'marketSum': 575},
#    {'itemcode': '371470',
#     'etfTabCode': 4,
# ...
#     'etfTabCode': 2,
#     'itemname': 'KINDEX Fn K-뉴딜디지털플러스',
#     'nowVal': 10740,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.37,
#     'nav': 10748.0,
#     'threeMonthEarnRate': -4.8466,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 54},
#    {'itemcode': '306530',
#     'etfTabCode': 3,
#     'itemname': 'HANARO 코스닥150선물레버리지',
#     'nowVal': 10150,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.3,
#     'nav': 10209.0,
#     'threeMonthEarnRate': 2.0675,
#     'quant': 408,
#     'amonut': 4,
#     'marketSum': 53},
#    {'itemcode': '292770',
#     'etfTabCode': 6,
#     'itemname': 'KODEX 국채선물3년인버스',
#     'nowVal': 51650,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 51591.0,
#     'threeMonthEarnRate': 1.7232,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 53},
#    {'itemcode': '299070',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물10년인버스',
#     'nowVal': 104465,
#     'risefall': '5',
#     'changeVal': -305,
#     'changeRate': -0.29,
#     'nav': 104750.0,
#     'threeMonthEarnRate': 4.1347,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 52},
#    {'itemcode': '253280',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 헬스케어',
#     'nowVal': 11580,
#     'risefall': '2',
#     'changeVal': 185,
#     'changeRate': 1.62,
#     'nav': 11599.0,
#     'threeMonthEarnRate': -2.8228,
#     'quant': 11935,
#     'amonut': 138,
#     'marketSum': 52},
#    {'itemcode': '277640',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 코스피대형주',
#     'nowVal': 13015,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.35,
#     'nav': 13019.0,
#     'threeMonthEarnRate': -4.4919,
#     'quant': 8,
#     'amonut': 0,
#     'marketSum': 52},
#    {'itemcode': '299080',
#     'etfTabCode': 6,
#     'itemname': 'KINDEX 국채선물3년인버스',
#     'nowVal': 103365,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 103279.0,
#     'threeMonthEarnRate': 1.7021,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 52},
#    {'itemcode': '275300',
#     'etfTabCode': 2,
#     'itemname': 'KODEX MSCI퀄리티',
#     'nowVal': 8600,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 8625.0,
#     'threeMonthEarnRate': -5.9081,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 52},
#    {'itemcode': '284980',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200금융',
#     'nowVal': 8885,
#     'risefall': '2',
#     'changeVal': 45,
#     'changeRate': 0.51,
#     'nav': 8915.0,
#     'threeMonthEarnRate': -6.0774,
#     'quant': 186,
#     'amonut': 1,
#     'marketSum': 52},
#    {'itemcode': '291620',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 코스닥150선물인버스',
#     'nowVal': 8310,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.36,
#     'nav': 8313.0,
#     'threeMonthEarnRate': -4.7946,
#     'quant': 902,
#     'amonut': 7,
#     'marketSum': 52},
#    {'itemcode': '267440',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물(H)',
#     'nowVal': 10140,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 0.55,
#     'nav': 10128.0,
#     'threeMonthEarnRate': -8.9391,
#     'quant': 5159,
#     'amonut': 52,
#     'marketSum': 51},
#    {'itemcode': '373490',
#     'etfTabCode': 2,
#     'itemname': 'KODEX K-이노베이션액티브',
#     'nowVal': 10135,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.15,
#     'nav': 10180.0,
#     'threeMonthEarnRate': -0.2858,
#     'quant': 78,
#     'amonut': 0,
#     'marketSum': 51},
#    {'itemcode': '334690',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물(H)',
#     'nowVal': 11240,
#     'risefall': '5',
#     'changeVal': -230,
#     'changeRate': -2.01,
#     'nav': 11249.0,
#     'threeMonthEarnRate': -14.8162,
#     'quant': 3444,
#     'amonut': 38,
#     'marketSum': 51},
#    {'itemcode': '291890',
#     'etfTabCode': 4,
#     'itemname': 'KODEX MSCI EM선물(H)',
#     'nowVal': 8270,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.48,
#     'nav': 8275.0,
#     'threeMonthEarnRate': -17.3135,
#     'quant': 46,
#     'amonut': 0,
#     'marketSum': 50},
#    {'itemcode': '145670',
#     'etfTabCode': 3,
#     'itemname': 'KINDEX 인버스',
#     'nowVal': 5475,
#     'risefall': '5',
#     'changeVal': -5,
#     'changeRate': -0.09,
#     'nav': 5473.0,
#     'threeMonthEarnRate': 4.8803,
#     'quant': 4214,
#     'amonut': 22,
#     'marketSum': 49},
#    {'itemcode': '412560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER KRX BBIG K-뉴딜레버리지',
#     'nowVal': 4670,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.43,
#     'nav': 4687.0,
#     'threeMonthEarnRate': -20.3768,
#     'quant': 272,
#     'amonut': 1,
#     'marketSum': 49},
#    {'itemcode': '391680',
#     'etfTabCode': 1,
#     'itemname': 'HK 하이볼액티브',
#     'nowVal': 8165,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.25,
#     'nav': 8190.0,
#     'threeMonthEarnRate': -4.9592,
#     'quant': 5,
#     'amonut': 0,
#     'marketSum': 49},
#    {'itemcode': '267490',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물레버리지(합성 H)',
#     'nowVal': 9675,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.89,
#     'nav': 9661.0,
#     'threeMonthEarnRate': -17.6471,
#     'quant': 2592,
#     'amonut': 25,
#     'marketSum': 48},
#    {'itemcode': '321410',
#     'etfTabCode': 7,
#     'itemname': 'KODEX 멀티에셋하이인컴(H)',
#     'nowVal': 9660,
#     'risefall': '2',
#     'changeVal': 40,
#     'changeRate': 0.42,
#     'nav': 9635.0,
#     'threeMonthEarnRate': -9.544,
#     'quant': 3,
#     'amonut': 0,
#     'marketSum': 48},
#    {'itemcode': '281990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 중소형고배당',
#     'nowVal': 12010,
#     'risefall': '5',
#     'changeVal': -45,
#     'changeRate': -0.37,
#     'nav': 12044.0,
#     'threeMonthEarnRate': 3.7078,
#     'quant': 153,
#     'amonut': 1,
#     'marketSum': 48},
#    {'itemcode': '253240',
#     'etfTabCode': 3,
#     'itemname': 'KOSEF 200선물인버스',
#     'nowVal': 5760,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.09,
#     'nav': 5763.0,
#     'threeMonthEarnRate': 4.3517,
#     'quant': 816,
#     'amonut': 4,
#     'marketSum': 48},
#    {'itemcode': '139290',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 경기소비재',
#     'nowVal': 15780,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.06,
#     'nav': 15808.0,
#     'threeMonthEarnRate': -0.8488,
#     'quant': 259,
#     'amonut': 4,
#     'marketSum': 47},
#    {'itemcode': '295820',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 200동일가중',
#     'nowVal': 10340,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.15,
#     'nav': 10375.0,
#     'threeMonthEarnRate': 0.3206,
#     'quant': 23,
#     'amonut': 0,
#     'marketSum': 47},
#    {'itemcode': '244660',
#     'etfTabCode': 2,
#     'itemname': 'KODEX 퀄리티Plus',
#     'nowVal': 9250,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 9324.0,
#     'threeMonthEarnRate': -5.2643,
#     'quant': 0,
#     'amonut': 0,
#     'marketSum': 46},
#    {'itemcode': '252410',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 200선물인버스',
#     'nowVal': 5745,
#     'risefall': '3',
#     'changeVal': 0,
#     'changeRate': 0.0,
#     'nav': 5736.0,
#     'threeMonthEarnRate': 4.8357,
#     'quant': 1036,
#     'amonut': 5,
#     'marketSum': 46},
#    {'itemcode': '371870',
#     'etfTabCode': 4,
#     'itemname': 'KINDEX 차이나항셍테크',
#     'nowVal': 5725,
#     'risefall': '5',
#     'changeVal': -155,
#     'changeRate': -2.64,
#     'nav': 5724.0,
#     'threeMonthEarnRate': -20.2712,
#     'quant': 10577,
#     'amonut': 61,
#     'marketSum': 46},
#    {'itemcode': '346000',
#     'etfTabCode': 6,
#     'itemname': 'HANARO KAP초장기국고채',
#     'nowVal': 39255,
#     'risefall': '5',
#     'changeVal': -225,
#     'changeRate': -0.57,
#     'nav': 39234.0,
#     'threeMonthEarnRate': -5.9709,
#     'quant': 744,
#     'amonut': 29,
#     'marketSum': 46},
#    {'itemcode': '267450',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물인버스(H)',
#     'nowVal': 9055,
#     'risefall': '5',
#     'changeVal': -25,
#     'changeRate': -0.28,
#     'nav': 9048.0,
#     'threeMonthEarnRate': 10.0606,
#     'quant': 1774,
#     'amonut': 16,
#     'marketSum': 45},
#    {'itemcode': '301440',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 코스피중형주',
#     'nowVal': 11295,
#     'risefall': '2',
#     'changeVal': 10,
#     'changeRate': 0.09,
#     'nav': 11328.0,
#     'threeMonthEarnRate': -1.4411,
#     'quant': 12,
#     'amonut': 0,
#     'marketSum': 45},
#    {'itemcode': '295020',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년인버스',
#     'nowVal': 52020,
#     'risefall': '5',
#     'changeVal': -90,
#     'changeRate': -0.17,
#     'nav': 52057.0,
#     'threeMonthEarnRate': 3.8461,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 45},
#    {'itemcode': '220130',
#     'etfTabCode': 4,
#     'itemname': 'SOL 중국본토 중소형 CSI500(합성 H)',
#     'nowVal': 4895,
#     'risefall': '2',
#     'changeVal': 55,
#     'changeRate': 1.14,
#     'nav': 4857.0,
#     'threeMonthEarnRate': -19.6681,
#     'quant': 124,
#     'amonut': 0,
#     'marketSum': 44},
#    {'itemcode': '301410',
#     'etfTabCode': 3,
#     'itemname': 'ARIRANG 코스닥150선물인버스',
#     'nowVal': 7245,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.41,
#     'nav': 7230.0,
#     'threeMonthEarnRate': -4.7152,
#     'quant': 5150,
#     'amonut': 37,
#     'marketSum': 43},
#    {'itemcode': '227560',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 200 생활소비재',
#     'nowVal': 9125,
#     'risefall': '2',
#     'changeVal': 75,
#     'changeRate': 0.83,
#     'nav': 9145.0,
#     'threeMonthEarnRate': -7.8412,
#     'quant': 1362,
#     'amonut': 12,
#     'marketSum': 42},
#    {'itemcode': '280940',
#     'etfTabCode': 5,
#     'itemname': 'KODEX 골드선물인버스(H)',
#     'nowVal': 6885,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.58,
#     'nav': 6961.0,
#     'threeMonthEarnRate': 1.1687,
#     'quant': 594,
#     'amonut': 4,
#     'marketSum': 41},
#    {'itemcode': '285010',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200중공업',
#     'nowVal': 9305,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.53,
#     'nav': 9306.0,
#     'threeMonthEarnRate': 5.0297,
#     'quant': 31648,
#     'amonut': 295,
#     'marketSum': 41},
#    {'itemcode': '157500',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 증권',
#     'nowVal': 4055,
#     'risefall': '2',
#     'changeVal': 30,
#     'changeRate': 0.75,
#     'nav': 4061.0,
#     'threeMonthEarnRate': -9.7736,
#     'quant': 3370,
#     'amonut': 13,
#     'marketSum': 40},
#    {'itemcode': '266550',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 중형주저변동50',
#     'nowVal': 10890,
#     'risefall': '5',
#     'changeVal': -50,
#     'changeRate': -0.46,
#     'nav': 10924.0,
#     'threeMonthEarnRate': 2.2143,
#     'quant': 2776,
#     'amonut': 30,
#     'marketSum': 38},
#    {'itemcode': '267500',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 미국장기국채선물인버스2X(합성 H)',
#     'nowVal': 7575,
#     'risefall': '5',
#     'changeVal': -55,
#     'changeRate': -0.72,
#     'nav': 7600.0,
#     'threeMonthEarnRate': 16.8453,
#     'quant': 6717,
#     'amonut': 50,
#     'marketSum': 38},
#    {'itemcode': '252730',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀로우볼',
#     'nowVal': 14935,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.2,
#     'nav': 14980.0,
#     'threeMonthEarnRate': -3.5823,
#     'quant': 4,
#     'amonut': 0,
#     'marketSum': 37},
#    {'itemcode': '333980',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KS퀄리티가중TR',
#     'nowVal': 14005,
#     'risefall': '2',
#     'changeVal': 35,
#     'changeRate': 0.25,
#     'nav': 14050.0,
#     'threeMonthEarnRate': -4.446,
#     'quant': 12,
#     'amonut': 0,
#     'marketSum': 35},
#    {'itemcode': '287300',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200건설',
#     'nowVal': 11280,
#     'risefall': '5',
#     'changeVal': -180,
#     'changeRate': -1.57,
#     'nav': 11304.0,
#     'threeMonthEarnRate': 0.6057,
#     'quant': 22790,
#     'amonut': 256,
#     'marketSum': 34},
#    {'itemcode': '275750',
#     'etfTabCode': 3,
#     'itemname': 'KBSTAR 코스닥150선물인버스',
#     'nowVal': 4820,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.31,
#     'nav': 4812.0,
#     'threeMonthEarnRate': -4.9165,
#     'quant': 4482,
#     'amonut': 21,
#     'marketSum': 34},
#    {'itemcode': '334700',
#     'etfTabCode': 5,
#     'itemname': 'KBSTAR 팔라듐선물인버스(H)',
#     'nowVal': 4735,
#     'risefall': '2',
#     'changeVal': 70,
#     'changeRate': 1.5,
#     'nav': 4762.0,
#     'threeMonthEarnRate': 5.6625,
#     'quant': 1624,
#     'amonut': 7,
#     'marketSum': 33},
#    {'itemcode': '280920',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG 주도업종',
#     'nowVal': 9140,
#     'risefall': '5',
#     'changeVal': -20,
#     'changeRate': -0.22,
#     'nav': 9172.0,
#     'threeMonthEarnRate': -5.7032,
#     'quant': 12,
#     'amonut': 0,
#     'marketSum': 32},
#    {'itemcode': '217790',
#     'etfTabCode': 2,
#     'itemname': 'TIGER 가격조정',
#     'nowVal': 22290,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.13,
#     'nav': 22334.0,
#     'threeMonthEarnRate': -0.7912,
#     'quant': 6,
#     'amonut': 0,
#     'marketSum': 31},
#    {'itemcode': '176710',
#     'etfTabCode': 6,
#     'itemname': '파워 중기국고채',
#     'nowVal': 96955,
#     'risefall': '2',
#     'changeVal': 160,
#     'changeRate': 0.17,
#     'nav': 96877.0,
#     'threeMonthEarnRate': -1.3011,
#     'quant': 1,
#     'amonut': 0,
#     'marketSum': 29},
#    {'itemcode': '278420',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG ESG우수기업',
#     'nowVal': 8945,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.06,
#     'nav': 8979.0,
#     'threeMonthEarnRate': 2.2532,
#     'quant': 1830,
#     'amonut': 16,
#     'marketSum': 27},
#    {'itemcode': '309210',
#     'etfTabCode': 2,
#     'itemname': 'ARIRANG KRX300헬스케어',
#     'nowVal': 8865,
#     'risefall': '2',
#     'changeVal': 150,
#     'changeRate': 1.72,
#     'nav': 8955.0,
#     'threeMonthEarnRate': -4.1255,
#     'quant': 190,
#     'amonut': 1,
#     'marketSum': 27},
#    {'itemcode': '301400',
#     'etfTabCode': 1,
#     'itemname': 'ARIRANG 코스닥150',
#     'nowVal': 12535,
#     'risefall': '2',
#     'changeVal': 20,
#     'changeRate': 0.16,
#     'nav': 12673.0,
#     'threeMonthEarnRate': 1.0496,
#     'quant': 284,
#     'amonut': 3,
#     'marketSum': 25},
#    {'itemcode': '285020',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200철강소재',
#     'nowVal': 8965,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.06,
#     'nav': 8983.0,
#     'threeMonthEarnRate': 7.3568,
#     'quant': 111,
#     'amonut': 0,
#     'marketSum': 23},
#    {'itemcode': '315480',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200커뮤니케이션서비스',
#     'nowVal': 14420,
#     'risefall': '5',
#     'changeVal': -15,
#     'changeRate': -0.1,
#     'nav': 14438.0,
#     'threeMonthEarnRate': -7.1466,
#     'quant': 10,
#     'amonut': 0,
#     'marketSum': 23},
#    {'itemcode': '252720',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 모멘텀밸류',
#     'nowVal': 13755,
#     'risefall': '5',
#     'changeVal': -30,
#     'changeRate': -0.22,
#     'nav': 13793.0,
#     'threeMonthEarnRate': -3.0046,
#     'quant': 3,
#     'amonut': 0,
#     'marketSum': 21},
#    {'itemcode': '295000',
#     'etfTabCode': 6,
#     'itemname': 'KBSTAR 국채선물10년',
#     'nowVal': 51000,
#     'risefall': '2',
#     'changeVal': 5,
#     'changeRate': 0.01,
#     'nav': 51005.0,
#     'threeMonthEarnRate': -3.4917,
#     'quant': 533,
#     'amonut': 27,
#     'marketSum': 20},
#    {'itemcode': '284990',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200에너지화학',
#     'nowVal': 11275,
#     'risefall': '5',
#     'changeVal': -120,
#     'changeRate': -1.05,
#     'nav': 11285.0,
#     'threeMonthEarnRate': 1.4512,
#     'quant': 177,
#     'amonut': 2,
#     'marketSum': 16},
#    {'itemcode': '287330',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200생활소비재',
#     'nowVal': 6900,
#     'risefall': '2',
#     'changeVal': 15,
#     'changeRate': 0.22,
#     'nav': 6918.0,
#     'threeMonthEarnRate': -7.3227,
#     'quant': 20,
#     'amonut': 0,
#     'marketSum': 12},
#    {'itemcode': '287310',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200경기소비재',
#     'nowVal': 9860,
#     'risefall': '5',
#     'changeVal': -40,
#     'changeRate': -0.4,
#     'nav': 9885.0,
#     'threeMonthEarnRate': -0.9901,
#     'quant': 174,
#     'amonut': 1,
#     'marketSum': 12},
#    {'itemcode': '287320',
#     'etfTabCode': 2,
#     'itemname': 'KBSTAR 200산업재',
#     'nowVal': 12125,
#     'risefall': '2',
#     'changeVal': 85,
#     'changeRate': 0.71,
#     'nav': 12134.0,
#     'threeMonthEarnRate': 9.9041,
#     'quant': 44,
#     'amonut': 0,
#     'marketSum': 7}]}}

# %% [markdown]
# ### JSON 에서 원하는 데이터 찾기

# %%
# result > etfItemList 의 하위 구조로 목록을 찾고자 하는 데이터를 가져옵니다.
# etfItemList
etfItemList = etf_json["result"]["etfItemList"]
etfItemList[0]
# Out:
# {'itemcode': '069500',
#  'etfTabCode': 1,
#  'itemname': 'KODEX 200',
#  'nowVal': 35020,
#  'risefall': '2',
#  'changeVal': 35,
#  'changeRate': 0.1,
#  'nav': 35032.0,
#  'threeMonthEarnRate': -4.7898,
#  'quant': 1850237,
#  'amonut': 64855,
#  'marketSum': 50201}

# %% [markdown]
# ## 데이터프레임 변환
# ### JSON 데이터를 pandas 의 데이터프레임 형태로 만들기

# %%
# 키-값 형태의 데이터를 데이터프레임으로 만듭니다.
# df
df = pd.DataFrame(etfItemList)
df
# Out:
#     itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0     069500           1              KODEX 200   35020        2         35
# 1     371460           4  TIGER 차이나전기차SOLACTIVE   13715        5        -55
# 2     122630           3             KODEX 레버리지   18555        2         30
# 3     133690           4         TIGER 미국나스닥100   68040        5       -165
# 4     214980           6         KODEX 단기채권PLUS  103885        3          0
# ..       ...         ...                    ...     ...      ...        ...
# 560   295000           6         KBSTAR 국채선물10년   51000        2          5
# 561   284990           2        KBSTAR 200에너지화학   11275        5       -120
# 562   287330           2        KBSTAR 200생활소비재    6900        2         15
# 563   287310           2        KBSTAR 200경기소비재    9860        5        -40
# 564   287320           2          KBSTAR 200산업재   12125        2         85
#
#      changeRate       nav  threeMonthEarnRate     quant  amonut  marketSum
# 0          0.10   35032.0             -4.7898   1850237   64855      50201
# 1         -0.40   13710.0            -10.4973   3333957   45914      34781
# 2          0.16   18593.0            -10.7229  11902227  221307      23166
# 3         -0.24   67261.0            -10.5943    161576   10986      19473
# 4          0.00  103883.0              0.2654     59834    6215      18969
# ..          ...       ...                 ...       ...     ...        ...
# 560        0.01   51005.0             -3.4917       533      27         20
# 561       -1.05   11285.0              1.4512       177       2         16
# 562        0.22    6918.0             -7.3227        20       0         12
# 563       -0.40    9885.0             -0.9901       174       1         12
# 564        0.71   12134.0              9.9041        44       0          7
#
# [565 rows x 12 columns]

# %% [markdown]
# ### 데이터 확인

# %%
# 데이터 프레임으로 잘 만들어 졌는지 상단 데이터의 일부만 미리보기 합니다.
df.head()
# Out:
#   itemcode  etfTabCode               itemname  nowVal risefall  changeVal  \
# 0   069500           1              KODEX 200   35020        2         35
# 1   371460           4  TIGER 차이나전기차SOLACTIVE   13715        5        -55
# 2   122630           3             KODEX 레버리지   18555        2         30
# 3   133690           4         TIGER 미국나스닥100   68040        5       -165
# 4   214980           6         KODEX 단기채권PLUS  103885        3          0
#
#    changeRate       nav  threeMonthEarnRate     quant  amonut  marketSum
# 0        0.10   35032.0             -4.7898   1850237   64855      50201
# 1       -0.40   13710.0            -10.4973   3333957   45914      34781
# 2        0.16   18593.0            -10.7229  11902227  221307      23166
# 3       -0.24   67261.0            -10.5943    161576   10986      19473
# 4        0.00  103883.0              0.2654     59834    6215      18969

# %%
# 데이터 프레임으로 잘 만들어 졌는지 하단 데이터의 일부만 미리보기 합니다.
df.tail()
# Out:
#     itemcode  etfTabCode         itemname  nowVal risefall  changeVal  \
# 560   295000           6   KBSTAR 국채선물10년   51000        2          5
# 561   284990           2  KBSTAR 200에너지화학   11275        5       -120
# 562   287330           2  KBSTAR 200생활소비재    6900        2         15
# 563   287310           2  KBSTAR 200경기소비재    9860        5        -40
# 564   287320           2    KBSTAR 200산업재   12125        2         85
#
#      changeRate      nav  threeMonthEarnRate  quant  amonut  marketSum
# 560        0.01  51005.0             -3.4917    533      27         20
# 561       -1.05  11285.0              1.4512    177       2         16
# 562        0.22   6918.0             -7.3227     20       0         12
# 563       -0.40   9885.0             -0.9901    174       1         12
# 564        0.71  12134.0              9.9041     44       0          7

# %% [markdown]
# ## 파일 저장
# ### 파일명 만들기

# %%
# 파이썬 표준라이브러리인 datetime을 불러옵니다.
# 날짜를 만들어 저장하기 위해 오늘 날짜를 구합니다.
from datetime import datetime

today = datetime.today().strftime("%Y.%m.%d") # 포매팅 암기

# %%
# f-string 방식으로 파일명을 만들어 줍니다.
# eft_날짜_raw.csv 형태로 만듭니다.
# file_name
file_name = f'eft_{today}_raw.csv'

# %% [markdown]
# ### 파일로 저장하고 불러오기

# %%
# csv 형태로 저장합니다. index 가 저장되지 않도록 합니다.
df.to_csv(file_name,index = False)

# %%
# 저장된 csv 파일을 읽어옵니다.
# itemcode 숫자 앞의 0 이 지워진다면 dtype={"itemcode": np.object} 로 타입을 지정해 주면 문자형태로 읽어옵니다.
pd.read_csv(file_name)
# Out:
#      itemcode  etfTabCode               itemname  nowVal  risefall  changeVal  \
# 0       69500           1              KODEX 200   35020         2         35
# 1      371460           4  TIGER 차이나전기차SOLACTIVE   13715         5        -55
# 2      122630           3             KODEX 레버리지   18555         2         30
# 3      133690           4         TIGER 미국나스닥100   68040         5       -165
# 4      214980           6         KODEX 단기채권PLUS  103885         3          0
# ..        ...         ...                    ...     ...       ...        ...
# 560    295000           6         KBSTAR 국채선물10년   51000         2          5
# 561    284990           2        KBSTAR 200에너지화학   11275         5       -120
# 562    287330           2        KBSTAR 200생활소비재    6900         2         15
# 563    287310           2        KBSTAR 200경기소비재    9860         5        -40
# 564    287320           2          KBSTAR 200산업재   12125         2         85
#
#      changeRate       nav  threeMonthEarnRate     quant  amonut  marketSum
# 0          0.10   35032.0             -4.7898   1850237   64855      50201
# 1         -0.40   13710.0            -10.4973   3333957   45914      34781
# 2          0.16   18593.0            -10.7229  11902227  221307      23166
# 3         -0.24   67261.0            -10.5943    161576   10986      19473
# 4          0.00  103883.0              0.2654     59834    6215      18969
# ..          ...       ...                 ...       ...     ...        ...
# 560        0.01   51005.0             -3.4917       533      27         20
# 561       -1.05   11285.0              1.4512       177       2         16
# 562        0.22    6918.0             -7.3227        20       0         12
# 563       -0.40    9885.0             -0.9901       174       1         12
# 564        0.71   12134.0              9.9041        44       0          7
#
# [565 rows x 12 columns]
